# %% [markdown]
# # Question: How did the revenue of Restaurant 1 and Restaurant 2 change over time?

# %%
sqlContext
# Out:
# Out[35]: <pyspark.sql.context.SQLContext at 0x7f2adb9acdc0>

# %% [markdown]
# ### Loading Orders data for both Restaurants

# %%
restaurant_1_orders = sqlContext.read.load('/FileStore/tables/restaurant_1_orders-2.csv', format='csv', header=True)

restaurant_2_orders = sqlContext.read.load('/FileStore/tables/restaurant_2_orders-2.csv', format='csv', header=True)

# %%
display(restaurant_1_orders)
display(restaurant_2_orders)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
restaurant_1_orders.dtypes
# Out:
# Out[38]: [('Order Number', 'string'),
#  ('Order Date', 'string'),
#  ('Item Name', 'string'),
#  ('Quantity', 'string'),
#  ('Product Price', 'string'),
#  ('Total products', 'string')]

# %% [markdown]
# ### We will make the following changes to the dataframes:
#  1. Change the 'Order Number' column to 'Order ID' for restaurant_1_orders.
#  2. Drop 'Item Name' and 'Total Products'.
#  3. Convert the 'Quantity' and 'Product Price' columns to integer and float respectively.

# %%
#1
restaurant_1_orders.withColumnRenamed('Order Number', 'Order ID')
# Out:
# Out[39]: DataFrame[Order ID: string, Order Date: string, Item Name: string, Quantity: string, Product Price: string, Total products: string]

# %%
restaurant_1_orders.withColumn(restaurant_1_orders.Quantity * restaurant_1_orders.).show()
# Out:
#   File <command-4224997869567725>:1
#     restaurant_1_orders.withColumn(restaurant_1_orders.Quantity * restaurant_1_orders.<Product Price>).show()
#                                                                                       ^
# SyntaxError: invalid syntax

# %%
#2
#restaurant_1_orders.withColumn("Quantity", resturant_1_orders.Quantity.cast('integer'))
